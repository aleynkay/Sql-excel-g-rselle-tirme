# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa1')

plt.figure(figsize=(20, 6))

plt.bar(df['Customer ID'], df['Order Count'],color='blue')

plt.title('Müşterilerin Sipariş Sayısı')
plt.xlabel('Customer ID')
plt.ylabel('Order Count')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa2')

plt.figure(figsize=(20, 6))

plt.bar(df['Product Name'], df['Satılan miktar'],color='blue')

plt.title('Ürünlerin Satılma Miktarları')
plt.xlabel('Product Name')
plt.ylabel('Satılan miktar')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa3')

plt.figure(figsize=(20, 6))

plt.bar(df['Product Name'], df['Gelir'],color='blue')
plt.title('Ürünlerden Elde Edilen Gelirler')
plt.xlabel('Product Name')
plt.ylabel('Gelir')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa4')

plt.figure(figsize=(20, 6))

plt.bar(df['Employee ID'], df['Performance'],color='green')
plt.title('Çalışanların Performansları')
plt.xlabel('Employee ID')
plt.ylabel('Performance')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa5')

plt.figure(figsize=(20, 6))

plt.bar(df['Ship City'], df['Satış miktarı'], color='green')

plt.title('Şehirlere Göre Satış Miktarları')
plt.xlabel('Ship City')
plt.ylabel('Satış Miktarı')
plt.xticks(rotation=90)

plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa6')

plt.figure(figsize=(20, 6))
plt.bar(df['Company Name'], df['Satış miktarı'],color='green')
plt.title('Tedarikçilere Göre Satış Miktarları')
plt.xlabel('Company Name')
plt.ylabel('Satış Miktarı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['Company Name'], df['toplam gelir'],color='blue')
plt.title('Tedarikçilere Göre toplam gelir')
plt.xlabel('Company Name')
plt.ylabel('Toplam Gelir')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa7')

plt.figure(figsize=(20, 6))
plt.bar(df['Category Name'], df['total sold'],color='green')
plt.title('Kategorilere Göre Satış Miktarları')
plt.xlabel('Category Name')
plt.ylabel('Satış Miktarı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['Category Name'], df['total income'],color='blue')
plt.title('Kategorilere Göre toplam gelir')
plt.xlabel('Category Name')
plt.ylabel('Toplam Gelir')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa8')

plt.figure(figsize=(20, 6))
plt.bar(df['yıllar'], df['toplam satış miktarı'],color='green')
plt.title('Yıllara Göre Satış Miktarları')
plt.xlabel('Yıllar')
plt.ylabel('Satış Miktarı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['yıllar'], df['toplam gelir'],color='blue')
plt.title('Yıllara Göre toplam gelir')
plt.xlabel('Yıllar')
plt.ylabel('Toplam Gelir')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa9')

plt.figure(figsize=(20, 6))
plt.bar(df['Customer ID'], df['toplam sipariş sayısı'],color='green')
plt.title('Müşterilere Göre Sipariş Sayısı')
plt.xlabel('Customer ID')
plt.ylabel('Sipariş Sayısı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['Customer ID'], df['toplam harcama miktarı'],color='blue')
plt.title('Müşterilere Göre Harcama Miktarı')
plt.xlabel('Customer ID')
plt.ylabel('HArcama Miktarı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel('veriler.xlsx', sheet_name='Sayfa10')

plt.figure(figsize=(20, 6))
plt.bar(df['Employee ID'], df['toplam sipariş sayısı'],color='green')
plt.title('Çalışanlara Göre Toplam Sipariş Sayısı')
plt.xlabel('Employee ID')
plt.ylabel('toplam sipariş sayısı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['Employee ID'], df['toplam satış miktarı'],color='blue')
plt.title('Çalışanlara Göre toplam satış miktarı')
plt.xlabel('Employee ID')
plt.ylabel('toplam satış miktarı')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()

plt.figure(figsize=(20, 6))
plt.bar(df['Employee ID'], df['toplam gelir'],color='red')
plt.title('Çalışanlara Göre toplam gelir')
plt.xlabel('Employee ID')
plt.ylabel('toplam gelir')
plt.xticks(rotation=90)
plt.grid(True)
plt.show()
